# %%
import os
import glob
import polars as pl
import pyarrow.csv as pv
import pyarrow.parquet as pq
import pyarrow.compute as pc
import pyarrow as pa

# --- 設定路徑 ---
# 假設你的102個CSV檔都放在這個資料夾
CSV_FOLDER = '../data' 
# 我們要將轉換後的Parquet檔存在這裡
PARQUET_OUTPUT_FOLDER = '../data/metro_data.parquet' 

# 確保輸出資料夾存在
os.makedirs(PARQUET_OUTPUT_FOLDER, exist_ok=True)

# --- 取得所有CSV檔案的路徑 ---
csv_files = glob.glob(f"{CSV_FOLDER}/臺北捷運*.csv")
print(f"找到 {len(csv_files)} 個CSV檔案。")
# Out:
# 找到 102 個CSV檔案。

# %%
# --- 開始轉換 ---
for i, file_path in enumerate(csv_files):
    print(f"處理中 ({i+1}/{len(csv_files)}): {os.path.basename(file_path)}")
    try:
        # 1) 讀 CSV：使用 schema_overrides（新版），先都當成字串或明確型別
        df_pl = pl.read_csv(
            file_path,
            schema_overrides={
                "日期": pl.Utf8,     # 先以字串讀入，稍後轉型
                "時段": pl.Utf8,     # 確保是字串
                "進站": pl.Utf8,
                "出站": pl.Utf8,
                "人次": pl.Int64
            },
            null_values=[""]        # 空字串視為 null
        )

        # 2) 清理與轉型：補人次的空值、將日期轉成 pl.Date（嘗試多種格式）
        df_pl = df_pl.with_columns(
            pl.col("人次").fill_null(0),
            pl.coalesce([
                pl.col("日期").str.strptime(pl.Date, format="%Y-%m-%d", strict=False),
                pl.col("日期").str.strptime(pl.Date, format="%Y/%m/%d", strict=False),
                pl.col("日期").str.strptime(pl.Date, format="%Y%m%d",   strict=False),
            ]).alias("日期")
        )

        # （可選）時段左側補零，統一成兩位數字串
        df_pl = df_pl.with_columns(
            pl.col("時段").str.zfill(2)
        )

        # 3) 轉成 PyArrow Table
        table = df_pl.to_arrow()  # 日期會是 date32 或 timestamp，兩者 pc.year 都支援

        # 4) year / month：先算，再 cast 到你要的寬度；用 append_column（不用 Field）
        years  = pc.cast(pc.year(table["日期"]),  pa.int16())
        months = pc.cast(pc.month(table["日期"]), pa.int8())

        table = table.append_column("year",  years)
        table = table.append_column("month", months)

        # 5) 寫入分區 Parquet 資料集
        pq.write_to_dataset(
            table,
            root_path=PARQUET_OUTPUT_FOLDER,
            partition_cols=["year", "month"],
            existing_data_behavior="overwrite_or_ignore"
        )

    except Exception as e:
        print(f"處理檔案 {os.path.basename(file_path)} 時發生致命錯誤: {e}")
        break

print("\n轉換流程完成！")
print(f"資料已儲存至: {PARQUET_OUTPUT_FOLDER}")
# Out:
# 處理中 (1/102): 臺北捷運每日分時各站OD流量統計資料_201701.csv
# 處理中 (2/102): 臺北捷運每日分時各站OD流量統計資料_201702.csv
# 處理中 (3/102): 臺北捷運每日分時各站OD流量統計資料_201703.csv
# 處理中 (4/102): 臺北捷運每日分時各站OD流量統計資料_201704.csv
# 處理中 (5/102): 臺北捷運每日分時各站OD流量統計資料_201705.csv
# 處理中 (6/102): 臺北捷運每日分時各站OD流量統計資料_201706.csv
# 處理中 (7/102): 臺北捷運每日分時各站OD流量統計資料_201707.csv
# 處理中 (8/102): 臺北捷運每日分時各站OD流量統計資料_201708.csv
# 處理中 (9/102): 臺北捷運每日分時各站OD流量統計資料_201709.csv
# 處理中 (10/102): 臺北捷運每日分時各站OD流量統計資料_201710.csv
# 處理中 (11/102): 臺北捷運每日分時各站OD流量統計資料_201711.csv
# 處理中 (12/102): 臺北捷運每日分時各站OD流量統計資料_201712.csv
# 處理中 (13/102): 臺北捷運每日分時各站OD流量統計資料_201801.csv
# 處理中 (14/102): 臺北捷運每日分時各站OD流量統計資料_201802.csv
# 處理中 (15/102): 臺北捷運每日分時各站OD流量統計資料_201803.csv
# 處理中 (16/102): 臺北捷運每日分時各站OD流量統計資料_201804.csv
# 處理中 (17/102): 臺北捷運每日分時各站OD流量統計資料_201805.csv
# 處理中 (18/102): 臺北捷運每日分時各站OD流量統計資料_201806.csv
# 處理中 (19/102): 臺北捷運每日分時各站OD流量統計資料_201807.csv
# 處理中 (20/102): 臺北捷運每日分時各站OD流量統計資料_201808.csv
# 處理中 (21/102): 臺北捷運每日分時各站OD流量統計資料_201809.csv
# 處理中 (22/102): 臺北捷運每日分時各站OD流量統計資料_201810.csv
# 處理中 (23/102): 臺北捷運每日分時各站OD流量統計資料_201811.csv
# 處理中 (24/102): 臺北捷運每日分時各站OD流量統計資料_201812.csv
# 處理中 (25/102): 臺北捷運每日分時各站OD流量統計資料_201901.csv
# 處理中 (26/102): 臺北捷運每日分時各站OD流量統計資料_201902.csv
# 處理中 (27/102): 臺北捷運每日分時各站OD流量統計資料_201903.csv
# 處理中 (28/102): 臺北捷運每日分時各站OD流量統計資料_201904.csv
# 處理中 (29/102): 臺北捷運每日分時各站OD流量統計資料_201905.csv
# 處理中 (30/102): 臺北捷運每日分時各站OD流量統計資料_201906.csv
# 處理中 (31/102): 臺北捷運每日分時各站OD流量統計資料_201907.csv
# 處理中 (32/102): 臺北捷運每日分時各站OD流量統計資料_201908.csv
# 處理中 (33/102): 臺北捷運每日分時各站OD流量統計資料_201909.csv
# 處理中 (34/102): 臺北捷運每日分時各站OD流量統計資料_201910.csv
# 處理中 (35/102): 臺北捷運每日分時各站OD流量統計資料_201911.csv
# 處理中 (36/102): 臺北捷運每日分時各站OD流量統計資料_201912.csv
# 處理中 (37/102): 臺北捷運每日分時各站OD流量統計資料_202001.csv
# 處理中 (38/102): 臺北捷運每日分時各站OD流量統計資料_202002.csv
# 處理中 (39/102): 臺北捷運每日分時各站OD流量統計資料_202003.csv
# 處理中 (40/102): 臺北捷運每日分時各站OD流量統計資料_202004.csv
# 處理中 (41/102): 臺北捷運每日分時各站OD流量統計資料_202005.csv
# 處理中 (42/102): 臺北捷運每日分時各站OD流量統計資料_202006.csv
# 處理中 (43/102): 臺北捷運每日分時各站OD流量統計資料_202007.csv
# 處理中 (44/102): 臺北捷運每日分時各站OD流量統計資料_202008.csv
# 處理中 (45/102): 臺北捷運每日分時各站OD流量統計資料_202009.csv
# 處理中 (46/102): 臺北捷運每日分時各站OD流量統計資料_202010.csv
# 處理中 (47/102): 臺北捷運每日分時各站OD流量統計資料_202011.csv
# 處理中 (48/102): 臺北捷運每日分時各站OD流量統計資料_202012.csv
# 處理中 (49/102): 臺北捷運每日分時各站OD流量統計資料_202101.csv
# 處理中 (50/102): 臺北捷運每日分時各站OD流量統計資料_202102.csv
# 處理中 (51/102): 臺北捷運每日分時各站OD流量統計資料_202103.csv
# 處理中 (52/102): 臺北捷運每日分時各站OD流量統計資料_202104.csv
# 處理中 (53/102): 臺北捷運每日分時各站OD流量統計資料_202105.csv
# 處理中 (54/102): 臺北捷運每日分時各站OD流量統計資料_202106.csv
# 處理中 (55/102): 臺北捷運每日分時各站OD流量統計資料_202107.csv
# 處理中 (56/102): 臺北捷運每日分時各站OD流量統計資料_202108.csv
# 處理中 (57/102): 臺北捷運每日分時各站OD流量統計資料_202109.csv
# 處理中 (58/102): 臺北捷運每日分時各站OD流量統計資料_202110.csv
# 處理中 (59/102): 臺北捷運每日分時各站OD流量統計資料_202111.csv
# 處理中 (60/102): 臺北捷運每日分時各站OD流量統計資料_202112.csv
# 處理中 (61/102): 臺北捷運每日分時各站OD流量統計資料_202201.csv
# 處理中 (62/102): 臺北捷運每日分時各站OD流量統計資料_202202.csv
# 處理中 (63/102): 臺北捷運每日分時各站OD流量統計資料_202203.csv
# 處理中 (64/102): 臺北捷運每日分時各站OD流量統計資料_202204.csv
# 處理中 (65/102): 臺北捷運每日分時各站OD流量統計資料_202205.csv
# 處理中 (66/102): 臺北捷運每日分時各站OD流量統計資料_202206.csv
# 處理中 (67/102): 臺北捷運每日分時各站OD流量統計資料_202207.csv
# 處理中 (68/102): 臺北捷運每日分時各站OD流量統計資料_202208.csv
# 處理中 (69/102): 臺北捷運每日分時各站OD流量統計資料_202209.csv
# 處理中 (70/102): 臺北捷運每日分時各站OD流量統計資料_202210.csv
# 處理中 (71/102): 臺北捷運每日分時各站OD流量統計資料_202211.csv
# 處理中 (72/102): 臺北捷運每日分時各站OD流量統計資料_202212.csv
# 處理中 (73/102): 臺北捷運每日分時各站OD流量統計資料_202301.csv
# 處理中 (74/102): 臺北捷運每日分時各站OD流量統計資料_202302.csv
# 處理中 (75/102): 臺北捷運每日分時各站OD流量統計資料_202303.csv
# 處理中 (76/102): 臺北捷運每日分時各站OD流量統計資料_202304.csv
# 處理中 (77/102): 臺北捷運每日分時各站OD流量統計資料_202305.csv
# 處理中 (78/102): 臺北捷運每日分時各站OD流量統計資料_202306.csv
# 處理中 (79/102): 臺北捷運每日分時各站OD流量統計資料_202307.csv
# 處理中 (80/102): 臺北捷運每日分時各站OD流量統計資料_202308.csv
# 處理中 (81/102): 臺北捷運每日分時各站OD流量統計資料_202309.csv
# 處理中 (82/102): 臺北捷運每日分時各站OD流量統計資料_202310.csv
# 處理中 (83/102): 臺北捷運每日分時各站OD流量統計資料_202311.csv
# 處理中 (84/102): 臺北捷運每日分時各站OD流量統計資料_202312.csv
# 處理中 (85/102): 臺北捷運每日分時各站OD流量統計資料_202401.csv
# 處理中 (86/102): 臺北捷運每日分時各站OD流量統計資料_202402.csv
# 處理中 (87/102): 臺北捷運每日分時各站OD流量統計資料_202403.csv
# 處理中 (88/102): 臺北捷運每日分時各站OD流量統計資料_202404.csv
# 處理中 (89/102): 臺北捷運每日分時各站OD流量統計資料_202405.csv
# 處理中 (90/102): 臺北捷運每日分時各站OD流量統計資料_202406.csv
# 處理中 (91/102): 臺北捷運每日分時各站OD流量統計資料_202407.csv
# 處理中 (92/102): 臺北捷運每日分時各站OD流量統計資料_202408.csv
# 處理中 (93/102): 臺北捷運每日分時各站OD流量統計資料_202409.csv
# 處理中 (94/102): 臺北捷運每日分時各站OD流量統計資料_202410.csv
# 處理中 (95/102): 臺北捷運每日分時各站OD流量統計資料_202411.csv
# 處理中 (96/102): 臺北捷運每日分時各站OD流量統計資料_202412.csv
# 處理中 (97/102): 臺北捷運每日分時各站OD流量統計資料_202501.csv
# 處理中 (98/102): 臺北捷運每日分時各站OD流量統計資料_202502.csv
# 處理中 (99/102): 臺北捷運每日分時各站OD流量統計資料_202503.csv
# 處理中 (100/102): 臺北捷運每日分時各站OD流量統計資料_202504.csv
# 處理中 (101/102): 臺北捷運每日分時各站OD流量統計資料_202505.csv
# 處理中 (102/102): 臺北捷運每日分時各站OD流量統計資料_202506.csv
#
# 轉換流程完成！
# 資料已儲存至: ../data/metro_data.parquet

# %%
import duckdb
import pandas as pd

PARQUET_PATH = r"../data/metro_data.parquet"  # ← 改成你的 Parquet 根目錄

con = duckdb.connect()

# 1) 先把「日期+時段」合成 time，並把人次彙總為每站×每小時的進/出
#    注意：用 strptime()，且對「時段」左側補零成兩位數
sql = f"""
WITH base AS (
  SELECT
    CAST(日期 AS DATE) AS 日期,
    lpad(CAST(時段 AS VARCHAR), 2, '0') AS 時段,
    進站,
    出站,
    人次
  FROM parquet_scan('{PARQUET_PATH}/**/*.parquet')
),
io AS (
  -- 進站：以「進站」欄位當車站
  SELECT
    strptime(CAST(日期 AS VARCHAR) || ' ' || 時段 || ':00:00', '%Y-%m-%d %H:%M:%S') AS time,
    進站 AS station,
    SUM(人次) AS entries,
    0::BIGINT AS exits
  FROM base
  GROUP BY 1,2

  UNION ALL

  -- 出站：以「出站」欄位當車站
  SELECT
    strptime(CAST(日期 AS VARCHAR) || ' ' || 時段 || ':00:00', '%Y-%m-%d %H:%M:%S') AS time,
    出站 AS station,
    0::BIGINT AS entries,
    SUM(人次) AS exits
  FROM base
  GROUP BY 1,2
),
agg AS (
  SELECT
    time,
    station,
    SUM(entries) AS total_entries,
    SUM(exits)   AS total_exits
  FROM io
  GROUP BY 1,2
)

-- 這裡不 pivot，先拉回 Python 做寬表
SELECT * FROM agg
ORDER BY time, station
"""

agg_df = con.execute(sql).df()

# 2) 進站寬表：row=time, columns=station, values=total_entries
entries_df = (
    agg_df.loc[:, ["time", "station", "total_entries"]]
          .pivot(index="time", columns="station", values="total_entries")
          .sort_index()
    .fillna(0)
)

# 3) 出站寬表：row=time, columns=station, values=total_exits
exits_df = (
    agg_df.loc[:, ["time", "station", "total_exits"]]
          .pivot(index="time", columns="station", values="total_exits")
          .sort_index()
    .fillna(0)
)

# 4) 依需求轉型（可選）：整數更直觀；若有 NA 已被填 0
entries_df = entries_df.astype("int64")
exits_df   = exits_df.astype("int64")

# 5) 輸出 CSV（含索引當作 time 欄）
entries_out = "../data/entries_by_station_hour.csv"
exits_out   = "../data/exits_by_station_hour.csv"
entries_df.to_csv(entries_out, encoding="utf-8-sig", index=True, index_label="time")
exits_df.to_csv(exits_out, encoding="utf-8-sig", index=True, index_label="time")

print("Saved:", entries_out, exits_out)
# Out:
# Saved: ../data/entries_by_station_hour.csv ../data/exits_by_station_hour.csv
